# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service

# %%
import time
import pandas as pd
import random
from tqdm import tqdm

# %%
base = 'https://www.yanolja.com'
url = base + '/hotel/r-900582?lat=37.50681&lng=127.06624&advert=AREA&topAdvertiseMore=3&sort=105&placeListType=hotel&pathDivision=r-900582'
driver = webdriver.Chrome('./chromedriver.exe')
driver.get(url)  #페이지열기
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_3508\3288815520.py:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome('./chromedriver.exe')

# %%
num = random.randrange(3,5)
lines=[]

base = 'https://www.yanolja.com'
url = base + '/hotel/r-900582?lat=37.50681&lng=127.06624&advert=AREA&topAdvertiseMore=3&sort=105&placeListType=hotel&pathDivision=r-900582'
driver = webdriver.Chrome()
driver.get(url)  #페이지열기

last_height = driver.execute_script("return document.body.scrollHeight")
while True:
    # 끝까지 스크롤 다운
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")

    # 2초 대기
    time.sleep(2)

    # 스크롤 다운 후 스크롤 높이 다시 가져옴
    new_height = driver.execute_script("return document.body.scrollHeight")
    if new_height == last_height: # 현재 높이와 끝의 높이가 같을 시 종료
        break
    #last_height를 업데이트
    last_height = new_height
    
soup = BeautifulSoup(driver.page_source,'html.parser')
lis = soup.find_all('div',attrs={'class':'PlaceListItemText_container__fUIgA text-unit'})
time.sleep(10)
for li in tqdm(lis):
    ganswer_list=[]
    banswer_list=[]
    atag = []
    price = li.find('span',attrs={'class':'PlacePriceInfo_salePrice__28VZD'}).text.replace('원','').replace(',','')
    href = li.find('a')['href']
    sub_url = base+href
    driver.get(sub_url)
    time.sleep(num)
    soup = BeautifulSoup(driver.page_source,'html.parser')
    try:
        cnt = int(soup.find('span',attrs={'class':'css-id2b0n'}).text.replace('(','').replace(')','').replace(',',''))
    except:
        cnt = 0
    title = soup.find('div',attrs={'class':'property-title'}).text #건물이름
    kind = soup.find('div',attrs={'class':'css-1xsh8xn'}).text.replace(' ','') #종류
    try:
        grad = soup.find('span',attrs={'css-1m0vwjv'}).text #평점
    except:
        grad='null'
    dist = soup.find('span',attrs={'css-1tv2ofu'}).text #역과의 거리
    tags = soup.select('ul.css-17yp1q4 > div.css-t9n8kv > div.css-9cehu5')# 테그
    for tag in tags:
        tag = tag.text
        atag.append(tag)
            
    driver.find_element(By.CSS_SELECTOR ,value='#__next > div > div > main > article > div:nth-child(2) > div > div.css-1urbzj6 > div > button:nth-child(4)').click()
    time.sleep(num)
    soup = BeautifulSoup(driver.page_source,'html.parser')
    room_num = soup.find('div',attrs={'class':'description'}).text.replace('개','') # 총객실수
    try:
        if cnt >= 200:        
            driver.find_element(By.CSS_SELECTOR ,value='#__next > div > div > main > article > div:nth-child(2) > div > div.css-1urbzj6 > div > button:nth-child(5)').click()
            time.sleep(1)
            driver.find_element(By.XPATH ,value='//*[@id="__next"]/div/div/main/article/div[2]/div/div[2]/div/div[2]/div/div[2]/div[1]').click()
            time.sleep(2)
            driver.find_element(By.CSS_SELECTOR ,value='###').click()
            time.sleep(1)
            i = 0
            last_height = driver.execute_script("return document.body.scrollHeight")
            while i<4:
                i=i+1
                # 끝까지 스크롤 다운
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(1)
                # 스크롤 다운 후 스크롤 높이 다시 가져옴
                new_height = driver.execute_script("return document.body.scrollHeight")
                if new_height == last_height:
                    break
                last_height = new_height
            soup = BeautifulSoup(driver.page_source,'html.parser')    
            gdivs = soup.find_all('div',attrs={'class':'css-1wnvjz2'}) #후기
            for gdiv in gdivs:
                gdiv=gdiv.text
                ganswer_list.append(gdiv)
                
            driver.get(sub_url)    
            time.sleep(1)
            driver.find_element(By.CSS_SELECTOR ,value='#__next > div > div > main > article > div:nth-child(2) > div > div.css-1urbzj6 > div > button:nth-child(5)').click()
            time.sleep(1)
            #후기에서 별점 낮은순=====================  
            driver.find_element(By.XPATH ,value='//*[@id="__next"]/div/div/main/article/div[2]/div/div[2]/div/div[2]/div/div[2]/div[1]').click()
            time.sleep(2)  
            driver.find_element(By.XPATH ,value='//*[@id="BOTTOM_SHEET"]/div[2]/li[3]').click()
            time.sleep(1)
            #페이지다운 5번시작=====================        
            i = 0
            last_height = driver.execute_script("return document.body.scrollHeight")
            while i<4:
                i=i+1
                # 끝까지 스크롤 다운
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                # 1초 대기
                time.sleep(1)
                # 스크롤 다운 후 스크롤 높이 다시 가져옴
                new_height = driver.execute_script("return document.body.scrollHeight")
                if new_height == last_height:
                    break
                last_height = new_height
            #페이지다운 5번끝=====================        
            #100개의 후기정보를 받아와 추가시작=====================        
            soup = BeautifulSoup(driver.page_source,'html.parser')    
            bdivs = soup.find_all('div',attrs={'class':'css-1wnvjz2'}) #후기 
            for bdiv in bdivs:
                bdiv=bdiv.text
                banswer_list.append(bdiv)
            #100개의 후기정보를 받아와 추가끝=====================        
            #후기 별점 낮은순 끝=====================                
        elif cnt<200:
            driver.find_element(By.CSS_SELECTOR ,value='#__next > div > div > main > article > div:nth-child(2) > div > div.css-1urbzj6 > div > button:nth-child(5)').click()
            time.sleep(1)
            driver.find_element(By.XPATH ,value='//*[@id="__next"]/div/div/main/article/div[2]/div/div[2]/div/div[2]/div/div[2]/div[1]').click()
            time.sleep(2)
            driver.find_element(By.CSS_SELECTOR ,value='#BOTTOM_SHEET > div.css-gqqlqe > li:nth-child(2)').click()
            time.sleep(1)
            last_height = driver.execute_script("return document.body.scrollHeight")
            while True:
                driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
                time.sleep(1)
                new_height = driver.execute_script("return document.body.scrollHeight")
                if new_height == last_height:
                    break
                last_height = new_height
            soup = BeautifulSoup(driver.page_source,'html.parser')    
            gdivs = soup.find_all('div',attrs={'class':'css-1wnvjz2'}) #후기
            for gdiv in gdivs:
                gdiv=gdiv.text
                ganswer_list.append(gdiv) 
        elif cnt == 0:
            pass
    except:
        trash=0
    
    driver.get(sub_url)
    time.sleep(num)    
    try:
        driver.find_element(By.CSS_SELECTOR,'#__next > div > div > main > article > div:nth-child(2) > div > div.css-1urbzj6 > div > button:nth-child(2)').click()
    except:
        driver.find_element(By.CSS_SELECTOR,'#property-sticky-header__portal > div > button:nth-child(2)').click()
    time.sleep(1)
    soup = BeautifulSoup(driver.page_source,'html.parser')
    gps = soup.find('div',attrs={'class':'css-o8j33g'}).select('div')[0].text #위치
        
    lines.append([title,kind,grad,price,dist,atag,ganswer_list,banswer_list,gps,room_num,cnt])
    time.sleep(num)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 370/370 [3:31:00<00:00, 34.22s/it]

# %%
df = pd.DataFrame(lines)

# %%
df.to_csv('야놀자호텔.csv',index=False, encoding='utf-8-sig' )

# %%
a = pd.read_csv('./야놀자호텔.csv',encoding='utf8')

# %%
a
# Out:
#                           이름      종류   평점      가격  \
# 0              앰배서더 서울 풀만 호텔  프리미엄호텔  4.8  250000
# 1                    글래드 여의도     4성급  4.7  200640
# 2                     글래드 마포     4성급  4.8  143000
# 3                    더 리프 사당    일반호텔  4.3    예약마감
# 4    나인트리 프리미어 로카우스 호텔 서울 용산    일반호텔  4.7  158000
# ..                       ...     ...  ...     ...
# 365                  시티호텔 서울    일반호텔  2.8    예약마감
# 366                    라뉘 신촌    일반호텔  NaN    예약마감
# 367          이코노미호텔 명동 프리미어점    일반호텔  4.0    예약마감
# 368                신촌 메이저 호텔    일반호텔  4.3    예약마감
# 369                명동 사보이 호텔    일반호텔  3.5    예약마감
#
#                                    도보시간  \
# 0                       동대입구역 1번출구 250m
# 1                     국회의사당역 4번출구 도보 1분
# 2                              공덕역 바로 앞
# 3    서울특별시 관악구 남현 1길 66 사당역 5번 출구 도보 1분
# 4                       용산역 1번 출구 도보 3분
# ..                                  ...
# 365                      회현역 1번출구 도보 2분
# 366                       신촌역 7번출구 250m
# 367                      명동역 6번출구 도보 1분
# 368                          신촌역 차량 약2분
# 369                     명동역 6번 출구 도보 1분
#
#                                                   인기테그  \
# 0    ['주차가능', '야외수영장', '수영장', '와이파이', '사우나', '클럽라운지...
# 1    ['주차가능', '조식운영', '와이파이', '객실금연', '레스토랑', '바', ...
# 2     ['주차가능', '와이파이', '객실금연', '피트니스', '어메니티', '비즈니스']
# 3    ['스파/월풀/욕조', '와이파이', '객실금연', '24시간데스크', '비즈니스'...
# 4    ['주차가능', '조식운영', '와이파이', '객실금연', '레스토랑', '연회장'...
# ..                                                 ...
# 365                                                 []
# 366                                   ['주차가능', '와이파이']
# 367                ['와이파이', '객실금연', '어메니티', '24시간데스크']
# 368                        ['주차가능', '와이파이', '24시간데스크']
# 369  ['PC라운지', '와이파이', '객실금연', '매점/편의점', '공항셔틀', '2...
#
#                                                    좋후기  \
# 0    ['시설에 비해 가격도 저렴합니당', '너무너무 깨끗하고 쾌적합니다.', '룸서비스...
# 1    ['정말 좋아요 말이 필요 없어요!', '컨디션은 항상 너무 좋네요! 최저가로 저렴...
# 2    ['너무 좋았습니다! 다음에 재방문할게요~~!', '자주 놀러가는 곳이에요', '완...
# 3    ['너무좋았어용', '너무 친절하시고 시설이 이쁘고 깔끔해서 좋았어요', '기념일 ...
# 4    ['호캉스하기 좋아요', '좋아용 이용 추천', '어린 아이들이 놀기 좋은 적당한 ...
# ..                                                 ...
# 365  ['아주 좋아요 !!', '새벽에 체크인했는데도 잘 맞아 주셨어요 전체적으로 시설깔...
# 366  ['좋아요 ㄹㅇ', '괜춘합니다', '여기 좋아요!', '좋았어요~', '늦게 잠만...
# 367  ['잘 쉬다 갑니다', '숙소는 고시원정도 크기이지만 난방이 잘되서 더웠고칫솔치약 ...
# 368  ['조앗다네요옹', '저렴하고 좋아요', '서비스가 너무 좋아서 편안하게 있다갑니다...
# 369  ['ㅋㅋㅋㅋㅋ', '호텔 뷰는 기대안했지만ㅎㅎㅎ놀랐어요 좀ㅎㅎ객실 들어가니 화장실에...
#
#                                                    안후기  \
# 0                                                   []
# 1    ['데이유즈 쪼매난 글씨에 속아 숙박전환 추가 55천원내고 아주 식겁시키네요', '...
# 2    ['난방이 안되는 호텔춥다고 했더니 체크인시 얘기했는데 어쩌라는 호텔', '지방에 ...
# 3                                                   []
# 4                                                   []
# ..                                                 ...
# 365                                                 []
# 366                                                 []
# 367                                                 []
# 368                                                 []
# 369                                                 []
#
#                             위치  객실수   총후기
# 0             서울특별시 중구 동호로 287  269   169
# 1          서울특별시 영등포구 의사당대로 16  319  4416
# 2            서울특별시 마포구 마포대로 92  378  7717
# 3            서울특별시 관악구 남현1길 66  한국어    77
# 4         서울특별시 용산구 한강대로23길 25  274    36
# ..                         ...  ...   ...
# 365          서울특별시 중구 퇴계로4길 69  한국어    29
# 366        서울특별시 마포구 서강로20길 20   98     0
# 367           서울특별시 중구 명동8나길 9  한국어    18
# 368  서울특별시 마포구 서강로18길 8 (노고산동)   18    21
# 369          서울특별시 중구 명동8나길 10  105     2
#
# [370 rows x 11 columns]
