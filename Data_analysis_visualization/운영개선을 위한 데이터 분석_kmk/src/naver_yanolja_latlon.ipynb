# %%
import pandas as pd
import numpy as np
import re
import os
from tqdm import tqdm

# %%
naver_df = pd.read_csv('../../naver_crw/DAOU/test_large_out_v3.csv', index_col=0, encoding='euc-kr')

# %%
naver_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6664 entries, 0 to 6663
# Data columns (total 27 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   사업장명                    6664 non-null   object
#  1   업소유형                    874 non-null    object
#  2   업태구분명                   6664 non-null   object
#  3   지번주소                    6653 non-null   object
#  4   도로명주소                   3986 non-null   object
#  5   가까운 지하철역                5774 non-null   object
#  6   지하철역과의 거리               6664 non-null   float64
#  7   도보시간                    6664 non-null   float64
#  8   위도                      5774 non-null   float64
#  9   경도                      5774 non-null   float64
#  10  별점                      310 non-null    float64
#  11  방문자 리뷰수                 685 non-null    object
#  12  블로그 리뷰수                 513 non-null    object
#  13  한실수                     5434 non-null   float64
# ...

# %%
yanolja_df = pd.read_excel('../DABA/middle2.xlsx')
yanolja_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1221 entries, 0 to 1220
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   이름         1221 non-null   object
#  1   종류         1221 non-null   object
#  2   평점         1215 non-null   float64
#  3   숙박가격       1221 non-null   int64
#  4   도보시간       1221 non-null   object
#  5   인기테그       1221 non-null   object
#  6   별점 높은순 후기  1221 non-null   object
#  7   별점 낮은순 후기  1213 non-null   object
#  8   주소         1221 non-null   object
#  9   객실수        1203 non-null   object
#  10  총후기        1221 non-null   int64
#  11  대실가격       837 non-null    object
#  12  대실시간       815 non-null    object
#  13  위도         1221 non-null   float64
#  14  경도         1221 non-null   float64
# dtypes: float64(3), int64(2), object(10)
# memory usage: 143.2+ KB

# %%
naver_df['위도']
# Out:
# 0       37.563358
# 1       37.558934
# 2       37.561480
# 3       37.559108
# 4       37.559222
#           ...
# 6659    37.571482
# 6660    37.546468
# 6661    37.488098
# 6662    37.606978
# 6663    37.508734
# Name: 위도, Length: 6664, dtype: float64

# %%
yanolja_df['위도']
# Out:
# 0       37.560599
# 1       37.527409
# 2       37.542844
# 3       37.475718
# 4       37.527640
#           ...
# 1216    37.573042
# 1217    37.554856
# 1218    37.497175
# 1219    37.575017
# 1220    37.554960
# Name: 위도, Length: 1221, dtype: float64

# %%
print(len(yanolja_df[yanolja_df['위도'].isin(naver_df['위도'])])) # '1148' 개 ㅋ 
print(len(yanolja_df[~yanolja_df['위도'].isin(naver_df['위도'])])) # '1148' 개 ㅋ 
print(len(yanolja_df[yanolja_df['경도'].isin(naver_df['경도'])])) # '1148' 개 ㅋ 
print(len(yanolja_df[~yanolja_df['경도'].isin(naver_df['경도'])])) # '1148' 개 ㅋ

# %%
# 아에 같은 이름 있나 봐보기
print(len(yanolja_df[yanolja_df['위도'].isin(naver_df['위도'])])) # '1148' 개 ㅋ 
print(len(yanolja_df[~yanolja_df['위도'].isin(naver_df['위도'])])) # '1148' 개 ㅋ 

yanolja_df[~yanolja_df['위도'].isin(naver_df['위도'])]



# find_name_list = []

# for i in tqdm(range(naver_df.shape[0])):
# #for i in [0]:

#        target_lat = naver_df['위도'][i].upper().strip()
#        target_lon = naver_df['경도'][i].upper().strip()

#        count_list = []

#        for j in range(yanolja_df.shape[0]):

#               find_lat = yanolja_df['위도'][j].upper().strip()
#               find_lon = yanolja_df['경도'][j].upper().strip()
              
#               if np.isnan(target_lat) or np.isnan(find_lat): continue
#               if find_lat in find_lat:

#               count_list.append(count)

#               #print(f'네이버: {find_at}, 야놀자: {find_in}, {count}')
       
#        #print('-----max')
#        #print(f"네이버: {find_at}, 야놀자: {yanolja_df['위도'][find_idx_at_yanolja]}, {max(count_list)} {len(find_at)}")

#        if max(count_list) >= int(len(find_in)/2):
#               find_idx_at_yanolja = count_list.index(max(count_list))
#               find_name_list.append(yanolja_df['위도'][find_idx_at_yanolja])
#        else:
#               find_name_list.append(np.NAN)

# %%
yanolja_df[~yanolja_df['위도'].isin(naver_df['위도'])].to_csv('../DAIN/ll_not_equal_list.csv')

# %%
len(find_name_list)
# Out:
# 6664

# %%
print(find_name_list)
# Out:
# ['홍대 더 그레이 호텔                                    (The Gray HOTEL)', '명동 오요5(OYO5)', '더 스테이 클래식 호텔 명동', '몬드리안 서울 이태원(Mondrian Seoul Itaewon)', '명동(시청역) SEOUL CENTRAL HOTEL', nan, nan, nan, '홍대 더 그레이 호텔                                    (The Gray HOTEL)', nan, nan, '홍대 더 그레이 호텔                                    (The Gray HOTEL)', nan, nan, nan, nan, nan, '홍대 더 그레이 호텔                                    (The Gray HOTEL)', '홍대 더 그레이 호텔                                    (The Gray HOTEL)', '홍대 더 그레이 호텔                                    (The Gray HOTEL)', nan, '홍대 더 그레이 호텔                                    (The Gray HOTEL)', '홍대 더 그레이 호텔                                    (The Gray HOTEL)', '홍대 더 그레이 호텔                                    (The Gray HOTEL)', nan, '명동(을지로) HOTEL Mmmio (미오)', '명동(시청역) SEOUL CENTRAL HOTEL', '명동(을지로) HOTEL Mmmio (미오)', '홍대 더 그레이 호텔                                    (The Gray HOTEL)', nan, '홍대 더 그레이 호텔                                    (The Gray HOTEL)', '홍대
# ...

# %%
naver_df['사업장명2(야놀자키)'] = find_name_list

# %%
colum_names3 = ['사업장명','사업장명2(야놀자키)','업소유형','업태구분명','지번주소','도로명주소','위도','경도',
                '별점','방문자 리뷰수', '블로그 리뷰수', '지하철역과의 거리', '도보시간', '한실수','양실수','욕실수','구비시설',
                '네이버 이런점이 좋아요 총합', '네이버 이런점이 좋아요 {항목:좋아요수}', '데이터갱신일자',
                '인허가일자','인허가취소일자','영업상태코드','폐업일자','휴업시작일자','휴업종료일자','재개업일자']  # 27
len(colum_names3)
# Out:
# 27
