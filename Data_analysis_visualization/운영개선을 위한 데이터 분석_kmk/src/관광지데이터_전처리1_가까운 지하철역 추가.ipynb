# %%
import numpy as np
import pandas as pd
import geopy.distance
from tqdm import tqdm

# %%
#df = pd.read_csv('../DABA/middle_관광지위치.xlsx', encoding='euc-kr')
df = pd.read_excel('../DABA/middle_관광지위치.xlsx')
df
# Out:
#             경도       위도  중심시도명 중심시군구명           중심관광지명         Unnamed: 5  \
# 0     127.0591  37.5120  서울특별시    강남구              코엑스  서울 강남구 영동대로 513-0
# 1     127.0597  37.5087  서울특별시    강남구      현대백화점/무역센터점  서울 강남구 테헤란로 517-0
# 2     127.0275  37.5273  서울특별시    강남구      현대백화점/압구정본점  서울 강남구 압구정로 165-0
# 3     127.0416  37.5279  서울특별시    강남구  갤러리아백화점/명품관EAST  서울 강남구 압구정로 407-0
# 4     127.0400  37.5284  서울특별시    강남구  갤러리아백화점/명품관WEST  서울 강남구 압구정로 343-0
# ...        ...      ...    ...    ...              ...                ...
# 1731  127.0121  37.5672  서울특별시     중구           DDP패션몰     서울 중구 마장로 22-0
# 1732  126.9805  37.5620  서울특별시     중구            화폐박물관    서울 중구 남대문로 39-0
# 1733  127.0075  37.5694  서울특별시     중구             평화시장   서울 중구 청계천로 274-0
# 1734  126.9792  37.5548  서울특별시     중구           남산백범광장              서울 중구
# 1735  127.0106  37.5687  서울특별시     중구             맥스타일      서울 중구 마장로 3-0
#
#      중심카테고리 명_대 중심카테고리 명_중   순위
# 0           관광지       문화관광    1
# 1           관광지         쇼핑    2
# 2           관광지         쇼핑    3
# 3           관광지         쇼핑    4
# 4           관광지         쇼핑    5
# ...         ...        ...  ...
# 1731        관광지         쇼핑   93
# 1732        관광지       문화관광   94
# 1733        관광지         쇼핑   95
# 1734        관광지       문화관광   98
# 1735        관광지         쇼핑  100
#
# [1736 rows x 9 columns]

# %%
subway = pd.read_csv('../../naver_crw/DABA/서울시 역사마스터 정보.csv', encoding='euc-kr')

# %%
# 프라이머리 키 생성
subway['subway_pk'] = np.nan
for i in range(subway.shape[0]):
    #print(subway['역사명'][i], subway['호선'][i])
    subway['subway_pk'][i] = f"{subway['역사명'][i]}, {subway['호선'][i]}"
# Out:
# C:\Users\tjoeun\AppData\Local\Temp\ipykernel_10796\2159356481.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subway['subway_pk'][i] = f"{subway['역사명'][i]}, {subway['호선'][i]}"

# %%
# .. 가까운 지하철 거리 및 도보 시간 구하기
# 가까운 지하철 구하기

large_dist = []

for i in tqdm(range(df.shape[0])):
#for i in range(10):
    dummy = []

    if np.isnan(df.iloc[i]['위도']) :

        dummy.append(np.nan)
        find_min_j = np.nan
        find_stn_nam = np.nan
        find_stn_lat = np.nan
        find_stn_lon = np.nan
        nearest_stn = np.nan
        time_to_near = np.nan

    else:

        for j in range(subway.shape[0]):

            hotel_latlon = (df.iloc[i]['위도'], df.iloc[i]['경도'])
            subway_latlon = (subway.iloc[j]['경도'], subway.iloc[j]['위도'])    # 원본데이터에서 위경도 컬럼명 바뀌어 있음

            dist = geopy.distance.geodesic(hotel_latlon, subway_latlon).m
            dummy.append(dist)

        find_min_j = np.argmin(dummy)
        dist_to_stn = np.nanmin(dummy)
        time_to_stn = np.nanmin(dummy)/66.7

        #find_stn_nam = subway.iloc[find_min_j]['역사명']
        find_stn_nam = subway.iloc[find_min_j]['subway_pk']
        find_stn_lat = subway.iloc[find_min_j]['위도']
        find_stn_lon = subway.iloc[find_min_j]['경도']

        
            
        #print(f"호텔:{df.iloc[i]['사업장명']} {df.iloc[i]['지번주소']} {min(dummy)}m")
    large_dist.append([df.iloc[i]['중심관광지명'],
                        df.iloc[i]['Unnamed: 5'],
                        df.iloc[i]['위도'],
                        df.iloc[i]['경도'],
                        find_stn_nam,
                        find_stn_lat,
                        find_stn_lon,
                        dist_to_stn,
                        time_to_stn]) # 시속 4km --> 분속 66.7m
# Out:
# 100%|██████████| 1736/1736 [09:41<00:00,  2.99it/s]

# %%
find_large_dist = pd.DataFrame(large_dist, columns=['중심관광지명','주소','관광지 위도', '관광지 경도','가까운 지하철역', '역 위도','역 경도', '거리','도보시간(분)'])

#for i in range(10):
#    print(f"호텔:{large_df.iloc[i]['사업장명']}, {df.iloc[i]['거리']}")
find_large_dist.info()
find_large_dist
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   중심관광지명    1736 non-null   object
#  1   주소        1736 non-null   object
#  2   관광지 위도    1736 non-null   float64
#  3   관광지 경도    1736 non-null   float64
#  4   가까운 지하철역  1736 non-null   object
#  5   역 위도      1736 non-null   float64
#  6   역 경도      1736 non-null   float64
#  7   거리        1736 non-null   float64
#  8   도보시간(분)   1736 non-null   float64
# dtypes: float64(6), object(3)
# memory usage: 122.2+ KB
#                중심관광지명                 주소   관광지 위도    관광지 경도        가까운 지하철역  \
# 0                 코엑스  서울 강남구 영동대로 513-0  37.5120  127.0591    봉은사, 9호선(연장)
# 1         현대백화점/무역센터점  서울 강남구 테헤란로 517-0  37.5087  127.0597   삼성(무역센터), 2호선
# 2         현대백화점/압구정본점  서울 강남구 압구정로 165-0  37.5273  127.0275        압구정, 3호선
# 3     갤러리아백화점/명품관EAST  서울 강남구 압구정로 407-0  37.5279  127.0416     압구정로데오, 분당선
# 4     갤러리아백화점/명품관WEST  서울 강남구 압구정로 343-0  37.5284  127.0400     압구정로데오, 분당선
# ...               ...                ...      ...       ...             ...
# 1731           DDP패션몰     서울 중구 마장로 22-0  37.5672  127.0121  동대문역사문화공원, 2호선
# 1732            화폐박물관    서울 중구 남대문로 39-0  37.5620  126.9805  회현(남대문시장), 4호선
# 1733             평화시장   서울 중구 청계천로 274-0  37.5694  127.0075        동대문, 4호선
# 1734           남산백범광장              서울 중구  37.5548  126.9792  회현(남대문시장), 4호선
# 1735             맥스타일      서울 중구 마장로 3-0  37.5687  127.0106        동대문, 4호선
#
#             역 위도       역 경도          거리   도보시간(분)
# 0     127.060245  37.514219  266.273584  3.992108
# 1     127.063160  37.508844  306.333440  4.592705
# 2     127.028461  37.527072   88.635094  1.328862
# 3     127.040534  37.527381  110.438836  1.655755
# 4     127.040534  37.527381  122.551098  1.837348
# ...          ...        ...         ...       ...
# 1731  127.009054  37.565613  321.624542  4.821957
# 1732  126.978246  37.558514  435.150884  6.524001
# 1733  127.009287  37.570930  231.858960  3.476146
# 1734  126.978246  37.558514  420.740335  6.307951
# 1735  127.009287  37.570930  273.336696  4.098001
#
# [1736 rows x 9 columns]

# %%
df['가까운 지하철역'] = find_large_dist['가까운 지하철역']
df['지하철역과의 거리'] = find_large_dist['거리']
df['도보시간'] = find_large_dist['도보시간(분)']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   경도          1736 non-null   float64
#  1   위도          1736 non-null   float64
#  2   중심시도명       1736 non-null   object
#  3   중심시군구명      1736 non-null   object
#  4   중심관광지명      1736 non-null   object
#  5   Unnamed: 5  1736 non-null   object
#  6   중심카테고리 명_대  1736 non-null   object
#  7   중심카테고리 명_중  1736 non-null   object
#  8   순위          1736 non-null   int64
#  9   가까운 지하철역    1736 non-null   object
#  10  지하철역과의 거리   1736 non-null   float64
#  11  도보시간        1736 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 162.9+ KB

# %%
colum_names2 = ['경도',	'위도',	'중심시도명', '중심시군구명', '중심관광지명', 'Unnamed: 5', '중심카테고리 명_대', '중심카테고리 명_중', '순위','가까운 지하철역', '지하철역과의 거리', '도보시간']

df1 = df[colum_names2]
df1 = df1.rename({'Unnamed: 5':'주소'}, axis=1)
df1
# Out:
#             경도       위도  중심시도명 중심시군구명           중심관광지명                 주소  \
# 0     127.0591  37.5120  서울특별시    강남구              코엑스  서울 강남구 영동대로 513-0
# 1     127.0597  37.5087  서울특별시    강남구      현대백화점/무역센터점  서울 강남구 테헤란로 517-0
# 2     127.0275  37.5273  서울특별시    강남구      현대백화점/압구정본점  서울 강남구 압구정로 165-0
# 3     127.0416  37.5279  서울특별시    강남구  갤러리아백화점/명품관EAST  서울 강남구 압구정로 407-0
# 4     127.0400  37.5284  서울특별시    강남구  갤러리아백화점/명품관WEST  서울 강남구 압구정로 343-0
# ...        ...      ...    ...    ...              ...                ...
# 1731  127.0121  37.5672  서울특별시     중구           DDP패션몰     서울 중구 마장로 22-0
# 1732  126.9805  37.5620  서울특별시     중구            화폐박물관    서울 중구 남대문로 39-0
# 1733  127.0075  37.5694  서울특별시     중구             평화시장   서울 중구 청계천로 274-0
# 1734  126.9792  37.5548  서울특별시     중구           남산백범광장              서울 중구
# 1735  127.0106  37.5687  서울특별시     중구             맥스타일      서울 중구 마장로 3-0
#
#      중심카테고리 명_대 중심카테고리 명_중   순위        가까운 지하철역   지하철역과의 거리      도보시간
# 0           관광지       문화관광    1    봉은사, 9호선(연장)  266.273584  3.992108
# 1           관광지         쇼핑    2   삼성(무역센터), 2호선  306.333440  4.592705
# 2           관광지         쇼핑    3        압구정, 3호선   88.635094  1.328862
# 3           관광지         쇼핑    4     압구정로데오, 분당선  110.438836  1.655755
# 4           관광지         쇼핑    5     압구정로데오, 분당선  122.551098  1.837348
# ...         ...        ...  ...             ...         ...       ...
# 1731        관광지         쇼핑   93  동대문역사문화공원, 2호선  321.624542  4.821957
# 1732        관광지       문화관광   94  회현(남대문시장), 4호선  435.150884  6.524001
# 1733        관광지         쇼핑   95        동대문, 4호선  231.858960  3.476146
# 1734        관광지       문화관광   98  회현(남대문시장), 4호선  420.740335  6.307951
# 1735        관광지         쇼핑  100        동대문, 4호선  273.336696  4.098001
#
# [1736 rows x 12 columns]

# %%
output_path = "../DAOU/middle_관광지위치_지하철역추가.csv"
df1.to_csv(output_path, encoding='euc-kr')

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1736 entries, 0 to 1735
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   경도          1736 non-null   float64
#  1   위도          1736 non-null   float64
#  2   중심시도명       1736 non-null   object
#  3   중심시군구명      1736 non-null   object
#  4   중심관광지명      1736 non-null   object
#  5   Unnamed: 5  1736 non-null   object
#  6   중심카테고리 명_대  1736 non-null   object
#  7   중심카테고리 명_중  1736 non-null   object
#  8   순위          1736 non-null   int64
#  9   가까운 지하철역    1736 non-null   object
#  10  지하철역과의 거리   1736 non-null   float64
#  11  도보시간        1736 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 162.9+ KB
