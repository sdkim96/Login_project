# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc

# %%
mpl.rcParams['axes.unicode_minus'] = False
plt.rc('font', family='Malgun Gothic')

# %%
df = pd.read_excel('./숙소위치기반_교통_관광_통계정보_final.xlsx')

# %%
df
# Out:
#                            이름      종류   평점    숙박가격  \
# 0               앰배서더 서울 풀만 호텔  프리미엄호텔  4.8  250000
# 1                     글래드 여의도     4성급  4.7  200640
# 2                      글래드 마포     4성급  4.8  143000
# 3                     더 리프 사당    일반호텔  4.3  265000
# 4     나인트리 프리미어 로카우스 호텔 서울 용산    일반호텔  4.7  158000
# ...                       ...     ...  ...     ...
# 1201            서울 인사동알게스트하우스  게스트하우스  4.8   60000
# 1202              서울 룩스게스트하우스  게스트하우스  3.6   57000
# 1203         서울 Bottlehouse펜션  펜션/호스텔  4.0  108000
# 1204              서울 종로준오호텔펜션  펜션/호스텔  5.0   90000
# 1205           서울 홍대하얀집몽하우스펜션  펜션/호스텔  1.0  119000
#
#                                     도보시간  \
# 0                        동대입구역 1번출구 250m
# 1                      국회의사당역 4번출구 도보 1분
# 2                               공덕역 바로 앞
# 3     서울특별시 관악구 남현 1길 66 사당역 5번 출구 도보 1분
# 4                        용산역 1번 출구 도보 3분
# ...                                  ...
# 1201                             숙소 위치보기
# 1202                             숙소 위치보기
# 1203                             숙소 위치보기
# 1204                             숙소 위치보기
# 1205                             숙소 위치보기
#
#                                                    인기테그  \
# 0     ['주차가능', '야외수영장', '수영장', '와이파이', '사우나', '클럽라운지...
# 1     ['주차가능', '조식운영', '와이파이', '객실금연', '레스토랑', '바', ...
# 2      ['주차가능', '와이파이', '객실금연', '피트니스', '어메니티', '비즈니스']
# 3     ['스파/월풀/욕조', '와이파이', '객실금연', '24시간데스크', '비즈니스'...
# 4     ['주차가능', '조식운영', '와이파이', '객실금연', '레스토랑', '연회장'...
# ...                                                 ...
# 1201                                           ['와이파이']
# 1202                                           ['와이파이']
# 1203                                   ['와이파이', '독채객실']
# 1204                                    ['와이파이', '상비약']
# 1205                                    ['와이파이', '상비약']
#
#                                               별점 높은순 후기  \
# 0     ['시설에 비해 가격도 저렴합니당', '너무너무 깨끗하고 쾌적합니다.', '룸서비스...
# 1     ['정말 좋아요 말이 필요 없어요!', '컨디션은 항상 너무 좋네요! 최저가로 저렴...
# 2     ['너무 좋았습니다! 다음에 재방문할게요~~!', '자주 놀러가는 곳이에요', '완...
# 3     ['너무좋았어용', '너무 친절하시고 시설이 이쁘고 깔끔해서 좋았어요', '기념일 ...
# 4     ['호캉스하기 좋아요', '좋아용 이용 추천', '어린 아이들이 놀기 좋은 적당한 ...
# ...                                                 ...
# 1201  ['사장님너무친절하시고따뜻방이라 너무좋앗습니다', '깨끗하고 자취방 같이 아늑합니다...
# 1202  ['수건 많음, 화장실은 살짝 냄새남, 잠 자기에는 편했음, 이불이 푹신했음', '...
# 1203  ['좋았어요!!!', '??숙소는 역근처 건물 3층에 위치하고 있어요. 찾아오기 어...
# 1204  ['숙소 깔끔하고 인테리어도 분위기 있어요! 특히 화장실 청소 잘되있습니다! 사장님...
# 1205  ['독립된 화장실이 있어서 9만원 정도에 방을 잡았습니다. 늦은 시간에 예약했다지만...
#
#                                               별점 낮은순 후기  \
# 0                                                    []
# 1     ['데이유즈 쪼매난 글씨에 속아 숙박전환 추가 55천원내고 아주 식겁시키네요', '...
# 2     ['난방이 안되는 호텔춥다고 했더니 체크인시 얘기했는데 어쩌라는 호텔', '지방에 ...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1201                                                 []
# 1202                                                 []
# 1203                                                 []
# 1204                                                 []
# 1205                                                 []
#
#                             주소  객실수  ...  지하철역_평균거리(1km내)  \
# 0             서울특별시 중구 동호로 287  269  ...             0.72
# 1          서울특별시 영등포구 의사당대로 16  319  ...             0.62
# 2            서울특별시 마포구 마포대로 92  378  ...             0.42
# 3            서울특별시 관악구 남현1길 66  한국어  ...             0.12
# 4         서울특별시 용산구 한강대로23길 25  274  ...             0.53
# ...                        ...  ...  ...              ...
# 1201     서울특별시 종로구 수표로28길 12-3  NaN  ...             0.55
# 1202     서울특별시 마포구 와우산로 156 5층  NaN  ...             0.58
# 1203  서울특별시 구로구 경인로25길 16 301호  NaN  ...             0.31
# 1204       서울특별시 종로구 인사동16길 6   NaN  ...             0.66
# 1205     서울특별시 마포구 와우산로 162-8   NaN  ...             0.59
#
#       교통유동인구_월평균승차수(1km내)  교통유동인구_월평균하차수(1km내)  교통유동인구_월평균승하차총계(1km내)  \
# 0                65461.18             66068.77              131529.95
# 1                44340.55             47327.44               91667.99
# 2                20412.48             20203.94               40616.42
# 3                50042.49             51264.60              101307.08
# 4                23528.91             23727.87               47256.78
# ...                   ...                  ...                    ...
# 1201             79574.44             78905.40              158479.84
# 1202             40666.26             40033.71               80699.97
# 1203              7937.43              7486.39               15423.81
# 1204             75400.56             73681.34              149081.91
# 1205             40906.59             40139.77               81046.36
#
#       관광지_수(1km내)  쇼핑몰_수(1km내)  관광지_최단거리(1km내)  관광지_평균거리(1km내)  \
# 0               6            6            0.61            0.82
# 1               9            2            0.19            0.63
# 2               3            3            0.70            0.79
# 3               9            3            0.16            0.71
# 4              15            7            0.13            0.50
# ...           ...          ...             ...             ...
# 1201           14            3            0.22            0.66
# 1202           24            8            0.04            0.58
# 1203            2            2            0.26            0.45
# 1204           23            4            0.09            0.60
# 1205           24            8            0.08            0.59
#
#       쇼핑몰_최단거리(1km내)  쇼핑몰_평균거리(1km내)
# 0               0.57            0.79
# 1               0.75            0.87
# 2               0.18            0.23
# 3               0.49            0.81
# 4               0.14            0.43
# ...              ...             ...
# 1201            0.38            0.62
# 1202            0.28            0.48
# 1203            0.09            0.43
# 1204            0.09            0.70
# 1205            0.23            0.47
#
# [1206 rows x 34 columns]

# %%
df.columns
# Out:
# Index(['이름', '종류', '평점', '숙박가격', '도보시간', '인기테그', '별점 높은순 후기', '별점 낮은순 후기',
#        '주소', '객실수', '총후기', '대실가격', '대실시간', '위도', '경도', '경쟁업소_수(1km내)',
#        '경쟁업소_최단거리(1km내)', '경쟁업소_최장거리(1km내)', '경쟁업소_평균거리(1km내)',
#        '버스정류장_수(1km내)', '지하철역_수(1km내)', '버스정류장_최단거리(1km내)', '버스정류장_평균거리(1km내)',
#        '지하철역_최단거리(1km내)', '지하철역_평균거리(1km내)', '교통유동인구_월평균승차수(1km내)',
#        '교통유동인구_월평균하차수(1km내)', '교통유동인구_월평균승하차총계(1km내)', '관광지_수(1km내)',
#        '쇼핑몰_수(1km내)', '관광지_최단거리(1km내)', '관광지_평균거리(1km내)', '쇼핑몰_최단거리(1km내)',
#        '쇼핑몰_평균거리(1km내)'],
#       dtype='object')

# %%
sns.histplot(df['경쟁업소_수(1km내)'], bins=30, kde=False, color='blue', edgecolor='black')
plt.xlabel('1km내 경쟁업소수')
plt.ylabel('빈도수')
plt.title('1km내 경쟁업소수')
plt.show()

# %%
sns.histplot(df['경쟁업소_수(1km내)'], bins=150, kde=False, color='blue', edgecolor='black')
plt.xlabel('1km내 경쟁업소수')
plt.ylabel('빈도수')
plt.xlim(0,20)
plt.title('1km내 경쟁업소수')
plt.show()

# %%
sns.histplot(df['버스정류장_수(1km내)'], bins=30, kde=False, color='blue', edgecolor='black')
plt.xlabel('1km내 버스정류장수')
plt.ylabel('빈도수')
plt.title('1km내 버스정류장수')
plt.show()

# %%
sns.histplot(df['지하철역_수(1km내)'], bins=15, kde=False, color='blue', edgecolor='black')
plt.xlabel('1km내 지하철역수')
plt.ylabel('빈도수')
plt.title('1km내 지하철역수')
plt.show()

# %%
sns.histplot(df['교통유동인구_월평균승하차총계(1km내)'], bins=15, kde=False, color='blue', edgecolor='black')
plt.xlabel('1km내 교통유동인구(월평균 승하차)')
plt.ylabel('빈도수')
plt.title('1km내 교통유동인구')
plt.show()

# %%
sns.histplot(df['관광지_수(1km내)'], bins=15, kde=False, color='blue', edgecolor='black')
plt.xlabel('1km내 관광지수')
plt.ylabel('빈도수')
plt.title('1km내 관광지수')
plt.show()

# %%
sns.histplot(df['쇼핑몰_수(1km내)'], bins=15, kde=False, color='blue', edgecolor='black')
plt.xlabel('1km내 쇼핑몰수')
plt.ylabel('빈도수')
plt.title('1km내 쇼핑몰수')
plt.show()

# %%
df
# Out:
#                            이름      종류   평점    숙박가격  \
# 0               앰배서더 서울 풀만 호텔  프리미엄호텔  4.8  250000
# 1                     글래드 여의도     4성급  4.7  200640
# 2                      글래드 마포     4성급  4.8  143000
# 3                     더 리프 사당    일반호텔  4.3  265000
# 4     나인트리 프리미어 로카우스 호텔 서울 용산    일반호텔  4.7  158000
# ...                       ...     ...  ...     ...
# 1201            서울 인사동알게스트하우스  게스트하우스  4.8   60000
# 1202              서울 룩스게스트하우스  게스트하우스  3.6   57000
# 1203         서울 Bottlehouse펜션  펜션/호스텔  4.0  108000
# 1204              서울 종로준오호텔펜션  펜션/호스텔  5.0   90000
# 1205           서울 홍대하얀집몽하우스펜션  펜션/호스텔  1.0  119000
#
#                                     도보시간  \
# 0                        동대입구역 1번출구 250m
# 1                      국회의사당역 4번출구 도보 1분
# 2                               공덕역 바로 앞
# 3     서울특별시 관악구 남현 1길 66 사당역 5번 출구 도보 1분
# 4                        용산역 1번 출구 도보 3분
# ...                                  ...
# 1201                             숙소 위치보기
# 1202                             숙소 위치보기
# 1203                             숙소 위치보기
# 1204                             숙소 위치보기
# 1205                             숙소 위치보기
#
#                                                    인기테그  \
# 0     ['주차가능', '야외수영장', '수영장', '와이파이', '사우나', '클럽라운지...
# 1     ['주차가능', '조식운영', '와이파이', '객실금연', '레스토랑', '바', ...
# 2      ['주차가능', '와이파이', '객실금연', '피트니스', '어메니티', '비즈니스']
# 3     ['스파/월풀/욕조', '와이파이', '객실금연', '24시간데스크', '비즈니스'...
# 4     ['주차가능', '조식운영', '와이파이', '객실금연', '레스토랑', '연회장'...
# ...                                                 ...
# 1201                                           ['와이파이']
# 1202                                           ['와이파이']
# 1203                                   ['와이파이', '독채객실']
# 1204                                    ['와이파이', '상비약']
# 1205                                    ['와이파이', '상비약']
#
#                                               별점 높은순 후기  \
# 0     ['시설에 비해 가격도 저렴합니당', '너무너무 깨끗하고 쾌적합니다.', '룸서비스...
# 1     ['정말 좋아요 말이 필요 없어요!', '컨디션은 항상 너무 좋네요! 최저가로 저렴...
# 2     ['너무 좋았습니다! 다음에 재방문할게요~~!', '자주 놀러가는 곳이에요', '완...
# 3     ['너무좋았어용', '너무 친절하시고 시설이 이쁘고 깔끔해서 좋았어요', '기념일 ...
# 4     ['호캉스하기 좋아요', '좋아용 이용 추천', '어린 아이들이 놀기 좋은 적당한 ...
# ...                                                 ...
# 1201  ['사장님너무친절하시고따뜻방이라 너무좋앗습니다', '깨끗하고 자취방 같이 아늑합니다...
# 1202  ['수건 많음, 화장실은 살짝 냄새남, 잠 자기에는 편했음, 이불이 푹신했음', '...
# 1203  ['좋았어요!!!', '??숙소는 역근처 건물 3층에 위치하고 있어요. 찾아오기 어...
# 1204  ['숙소 깔끔하고 인테리어도 분위기 있어요! 특히 화장실 청소 잘되있습니다! 사장님...
# 1205  ['독립된 화장실이 있어서 9만원 정도에 방을 잡았습니다. 늦은 시간에 예약했다지만...
#
#                                               별점 낮은순 후기  \
# 0                                                    []
# 1     ['데이유즈 쪼매난 글씨에 속아 숙박전환 추가 55천원내고 아주 식겁시키네요', '...
# 2     ['난방이 안되는 호텔춥다고 했더니 체크인시 얘기했는데 어쩌라는 호텔', '지방에 ...
# 3                                                    []
# 4                                                    []
# ...                                                 ...
# 1201                                                 []
# 1202                                                 []
# 1203                                                 []
# 1204                                                 []
# 1205                                                 []
#
#                             주소  객실수  ...  지하철역_평균거리(1km내)  \
# 0             서울특별시 중구 동호로 287  269  ...             0.72
# 1          서울특별시 영등포구 의사당대로 16  319  ...             0.62
# 2            서울특별시 마포구 마포대로 92  378  ...             0.42
# 3            서울특별시 관악구 남현1길 66  한국어  ...             0.12
# 4         서울특별시 용산구 한강대로23길 25  274  ...             0.53
# ...                        ...  ...  ...              ...
# 1201     서울특별시 종로구 수표로28길 12-3  NaN  ...             0.55
# 1202     서울특별시 마포구 와우산로 156 5층  NaN  ...             0.58
# 1203  서울특별시 구로구 경인로25길 16 301호  NaN  ...             0.31
# 1204       서울특별시 종로구 인사동16길 6   NaN  ...             0.66
# 1205     서울특별시 마포구 와우산로 162-8   NaN  ...             0.59
#
#       교통유동인구_월평균승차수(1km내)  교통유동인구_월평균하차수(1km내)  교통유동인구_월평균승하차총계(1km내)  \
# 0                65461.18             66068.77              131529.95
# 1                44340.55             47327.44               91667.99
# 2                20412.48             20203.94               40616.42
# 3                50042.49             51264.60              101307.08
# 4                23528.91             23727.87               47256.78
# ...                   ...                  ...                    ...
# 1201             79574.44             78905.40              158479.84
# 1202             40666.26             40033.71               80699.97
# 1203              7937.43              7486.39               15423.81
# 1204             75400.56             73681.34              149081.91
# 1205             40906.59             40139.77               81046.36
#
#       관광지_수(1km내)  쇼핑몰_수(1km내)  관광지_최단거리(1km내)  관광지_평균거리(1km내)  \
# 0               6            6            0.61            0.82
# 1               9            2            0.19            0.63
# 2               3            3            0.70            0.79
# 3               9            3            0.16            0.71
# 4              15            7            0.13            0.50
# ...           ...          ...             ...             ...
# 1201           14            3            0.22            0.66
# 1202           24            8            0.04            0.58
# 1203            2            2            0.26            0.45
# 1204           23            4            0.09            0.60
# 1205           24            8            0.08            0.59
#
#       쇼핑몰_최단거리(1km내)  쇼핑몰_평균거리(1km내)
# 0               0.57            0.79
# 1               0.75            0.87
# 2               0.18            0.23
# 3               0.49            0.81
# 4               0.14            0.43
# ...              ...             ...
# 1201            0.38            0.62
# 1202            0.28            0.48
# 1203            0.09            0.43
# 1204            0.09            0.70
# 1205            0.23            0.47
#
# [1206 rows x 34 columns]

# %%
# 약 50% 씩 선택

#condition0 = df['평점'] > 4.7
# 평점은 후기와 함께 분석. 여기는 위치정보결과 찾기

# 평점 평균이상인 숫자로 조건대입

condition1 = df['경쟁업소_수(1km내)'] < 20
condition2 = df['버스정류장_수(1km내)'] > 90
condition3 = df['지하철역_수(1km내)'] > 5
condition4 = df['교통유동인구_월평균승하차총계(1km내)'] > 50000
condition5 = df['관광지_수(1km내)'] > 10
condition6 = df['쇼핑몰_수(1km내)'] > 7

# Combine the conditions using logical operators (e.g., AND: &)
final_condition =  condition1 & condition2 & condition3 & condition4 & condition5 #& condition6

# Apply the condition to the DataFrame to select the desired rows
df[final_condition].sort_values('평점')
# Out:
#                         이름      종류   평점    숙박가격              도보시간  \
# 740            홍대 더휴식 아늑호텔      모텔  4.5  160000           숙소 위치보기
# 82              홍대 나인브릭 호텔    일반호텔  4.7  162000  홍대입구역 9번출구 도보 6분
# 101           아만티 호텔 서울 홍대     4성급  4.7  220000   홍대입구역 1번출구 543m
# 320  라이즈 오토그래프 컬렉션 바이 메리어트  프리미엄호텔  4.7  330000  홍대입구역 9번출구 도보 4분
#
#                                                   인기테그  \
# 740  ['객실내PC', '무료영화(OTT)', '게임', '와이파이', 'VOD', '어...
# 82                            ['주차가능', '와이파이', '비즈니스']
# 101  ['주차가능', '야외수영장', '조식운영', '와이파이', '객실금연', '레스토...
# 320  ['주차가능', '조식운영', '와이파이', '객실금연', '레스토랑', '바', ...
#
#                                              별점 높은순 후기  \
# 740  ['잘이용했습니다', '봉산동일격필살님 안녕하세요.더휴식 아늑 홍대지점 조정화 대리...
# 82   ['멋진곳에서 즐겁게 보내고 갑니다.', '잘쉬었다왔습니다 편하네요', '오랜만의 ...
# 101  ['깨끗하고 너무 좋습니다!', '너무좋아요 또 숙박하고싶어요', '너무 깨끗하고 ...
# 320  ['급 혼캉스에 너무 행복한시간 보냈어요\r근데 스마트티비로 넷플릭스 보기 어려워서...
#
#                                              별점 낮은순 후기  \
# 740                                                NaN
# 82   ['제가 이상한건진 모르겠지만 아무리 위치가 좋다해도 동네 모텔수준 인테리어와 시설...
# 101  ['청소상태ㅠㅠ', '안녕하십니까, 아만티 호텔 서울입니다.아만티 호텔 서울을 선택...
# 320  ['바 가지마세요  주문시킬려고 해도 종업원이 쌩깝니다', '가격 점점 떨어지네요 ...
#
#                             주소  객실수  ...  지하철역_평균거리(1km내)  \
# 740  서울특별시 마포구 동교로 162-7 (서교동)   38  ...             0.74
# 82          서울특별시 마포구 홍익로5길 32   94  ...             0.72
# 101         서울특별시 마포구 월드컵북로 31  한국어  ...             0.76
# 320  서울특별시 마포구 양화로 130 (라이즈호텔)  272  ...             0.67
#
#      교통유동인구_월평균승차수(1km내)  교통유동인구_월평균하차수(1km내)  교통유동인구_월평균승하차총계(1km내)  \
# 740             39597.55             40336.68               79934.23
# 82              38061.96             38585.09               76647.04
# 101             42918.14             42717.68               85635.83
# 320             36172.87             36447.87               72620.75
#
#      관광지_수(1km내)  쇼핑몰_수(1km내)  관광지_최단거리(1km내)  관광지_평균거리(1km내)  쇼핑몰_최단거리(1km내)  \
# 740           20            5            0.15            0.59            0.44
# 82            20            5            0.23            0.56            0.54
# 101           17            5            0.32            0.68            0.55
# 320           20            5            0.19            0.54            0.46
#
#      쇼핑몰_평균거리(1km내)
# 740            0.59
# 82             0.65
# 101            0.68
# 320            0.60
#
# [4 rows x 34 columns]

# %%
len(df)
# Out:
# 1206

# %%
len(df[condition1])
# Out:
# 901

# %%
len(df[condition2])
# Out:
# 684

# %%
len(df[condition3])
# Out:
# 400

# %%
len(df[condition4])
# Out:
# 1138

# %%
len(df[condition5])
# Out:
# 496

# %%
len(df[condition6])
# Out:
# 353

# %%
len(df[final_condition])
# Out:
# 14
